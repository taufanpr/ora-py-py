# %%
# !pip uninstall -y latexify-py
# !pip install latexify-py
# Out:
# WARNING: Skipping latexify-py as it is not installed.
# Collecting latexify-py
#   Downloading https://files.pythonhosted.org/packages/8c/6a/175030a092f1fb35d9e2e40eb00e9a7e69b792e09cabd14e97904a82ee67/latexify_py-0.0.7-py3-none-any.whl
# Requirement already satisfied: dill>=0.3.2 in /usr/local/lib/python3.6/dist-packages (from latexify-py) (0.3.2)
# Installing collected packages: latexify-py
# Successfully installed latexify-py-0.0.7

# %%
# Before running following cells, restart the runtime so that the installed
# module is activated.
import math
import latexify

# %%
@latexify.with_latex
def solve(a, b, c):
  return (-b + math.sqrt(b**2 - 4*a*c)) / (2*a)

print(solve(1, 4, 3))
print(solve)
print()
solve
# Out:
# -1.0
# \mathrm{solve}(a, b, c)\triangleq \frac{-b + \sqrt{b^{2} - 4ac}}{2a}
# <latexify.core.with_latex.<locals>._LatexifiedFunction at 0x7fd1172abc50>

# %%
@latexify.with_latex
def sinc(x):
  if x == 0:
    return 1
  else:
    return math.sin(x) / x

sinc
# Out:
# <latexify.core.with_latex.<locals>._LatexifiedFunction at 0x7fd1172b46a0>

# %%
# Elif or nested else-if are unrolled.
@latexify.with_latex
def fib(x):
  if x == 0:
    return 1
  elif x == 1:
    return 1
  else:
    return fib(x-1) + fib(x-2)

fib
# Out:
# <latexify.core.with_latex.<locals>._LatexifiedFunction at 0x7fd1172abda0>

# %%
# Some math symbols are converted automatically.
@latexify.with_latex
def greek(alpha, beta, gamma, Omega):
  return alpha * beta + math.gamma(gamma) + Omega

greek
# Out:
# <latexify.core.with_latex.<locals>._LatexifiedFunction at 0x7fd1172ab898>
